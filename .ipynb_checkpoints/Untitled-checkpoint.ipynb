# %%
#dependencies
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tweepy
import json
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
#twitter api
consumer_key ='gH9nMHjLbjIAfGleDL4P3PuFn'
consumer_secret ='tOMiozYpdAkuLCcDZmBPOjKmjqDlOjnCnis0zeOw0D2UL7waej'
access_token = '288849814-EpjPlFAmsfgJ2xmEXzJ46JtcUTnUbBTPs3bKf03Z'
access_token_secret ='5UBuxncFEYW8Xmf2UuLLYyXTkAHha1B1o64fbuwVHVt4o'

#Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target Account
target_user = "@BBC"

# Counter
counter = 1

# Variables for holding sentiments
sentiments = []

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        
        # Add sentiments for each tweet into an array
        sentiments.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        
        # Add to counter 
        counter = counter + 1
        
sentiments_pd_BBC =pd.DataFrame.from_dict(sentiments)
sentiments_pd_BBC.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0   -0.4767  Fri Mar 30 20:23:06 +0000 2018     0.846    0.154     0.000
# 1   -0.3182  Fri Mar 30 19:00:32 +0000 2018     0.723    0.277     0.000
# 2    0.6369  Fri Mar 30 18:41:56 +0000 2018     0.781    0.000     0.219
# 3   -0.5983  Fri Mar 30 18:01:02 +0000 2018     0.804    0.196     0.000
# 4    0.0000  Fri Mar 30 17:29:06 +0000 2018     1.000    0.000     0.000
#
#    Tweets Ago
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5

# %%
# Target Account
target_user = "@CNN"

# Counter
counter = 1

# Variables for holding sentiments
sentiments = []

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        
        # Add sentiments for each tweet into an array
        sentiments.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        
        # Add to counter 
        counter = counter + 1
        
sentiments_pd_CNN =pd.DataFrame.from_dict(sentiments)
sentiments_pd_CNN.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0   -0.6249  Sat Mar 31 00:44:38 +0000 2018     0.796    0.204     0.000
# 1    0.0000  Sat Mar 31 00:34:05 +0000 2018     1.000    0.000     0.000
# 2    0.6808  Sat Mar 31 00:22:11 +0000 2018     0.781    0.000     0.219
# 3    0.4215  Sat Mar 31 00:12:33 +0000 2018     0.877    0.000     0.123
# 4   -0.7783  Sat Mar 31 00:11:53 +0000 2018     0.570    0.430     0.000
#
#    Tweets Ago
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5

# %%
# Target Account
target_user = "@CBS"

# Counter
counter = 1

# Variables for holding sentiments
sentiments = []

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        
        # Add sentiments for each tweet into an array
        sentiments.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        
        # Add to counter 
        counter = counter + 1
        
sentiments_pd_CBS =pd.DataFrame.from_dict(sentiments)
sentiments_pd_CBS.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.4926  Fri Mar 30 16:50:00 +0000 2018     0.873    0.000     0.127
# 1    0.0000  Thu Mar 29 17:32:40 +0000 2018     1.000    0.000     0.000
# 2    0.0000  Thu Mar 29 17:30:02 +0000 2018     1.000    0.000     0.000
# 3    0.3818  Tue Mar 27 21:00:01 +0000 2018     0.680    0.108     0.212
# 4    0.2960  Tue Mar 27 17:00:00 +0000 2018     0.901    0.000     0.099
#
#    Tweets Ago
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5

# %%
# Target Account
target_user = "@FoxNews"

# Counter
counter = 1

# Variables for holding sentiments
sentiments = []

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        
        # Add sentiments for each tweet into an array
        sentiments.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        
        # Add to counter 
        counter = counter + 1
        
sentiments_pd_FX =pd.DataFrame.from_dict(sentiments)
sentiments_pd_FX.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.0000  Sat Mar 31 00:49:15 +0000 2018     1.000    0.000     0.000
# 1    0.0000  Sat Mar 31 00:42:05 +0000 2018     1.000    0.000     0.000
# 2   -0.7717  Sat Mar 31 00:35:55 +0000 2018     0.621    0.379     0.000
# 3   -0.1027  Sat Mar 31 00:29:30 +0000 2018     0.887    0.113     0.000
# 4    0.0000  Sat Mar 31 00:19:32 +0000 2018     0.433    0.284     0.284
#
#    Tweets Ago
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5

# %%
# Target Account
target_user = "@nytimes"

# Counter
counter = 1

# Variables for holding sentiments
sentiments = []

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        
        # Add sentiments for each tweet into an array
        sentiments.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        
        # Add to counter 
        counter = counter + 1
        
sentiments_pd_NYT =pd.DataFrame.from_dict(sentiments)
sentiments_pd_NYT.tail()
# Out:
#     Compound                            Date  Negative  Neutral  Positive  \
# 95    0.2500  Fri Mar 30 23:19:08 +0000 2018     0.567    0.165     0.268
# 96    0.0000  Fri Mar 30 23:00:04 +0000 2018     1.000    0.000     0.000
# 97    0.0000  Fri Mar 30 22:50:04 +0000 2018     1.000    0.000     0.000
# 98   -0.7096  Fri Mar 30 22:38:40 +0000 2018     0.772    0.228     0.000
# 99    0.2675  Fri Mar 30 22:28:28 +0000 2018     0.723    0.119     0.158
#
#     Tweets Ago
# 95          96
# 96          97
# 97          98
# 98          99
# 99         100

# %%
#get only compounds for each media outlet
BBC_comp = sentiments_pd_BBC['Compound']
CBS_comp = sentiments_pd_CBS['Compound']
CNN_comp = sentiments_pd_CNN['Compound']
FX_comp = sentiments_pd_FX['Compound']
NYT_comp = sentiments_pd_NYT['Compound']

#set colors for city type
color_scheme = {'cadetblue2':'#8EE5EE', 'cobaltgreen':'#3D9140', 'crimson':'#DC143C', 'cobalt':'#3D59AB', 'gold1':'#FFD700'}
newscolors = {'bbc': color_scheme['cadetblue2'], 'cbs': color_scheme['cobaltgreen'], 'cnn': color_scheme['crimson'], 'fox': color_scheme['cobalt'], 'nytimes': color_scheme['gold1']} 

#create scatter plot for all media compound tweets
bbc_scatter = plt.scatter(np.arange(len(BBC_comp)), BBC_comp, marker = 'o', color = newscolors['bbc'] , label = 'BBC', alpha = .75)
cbs_scatter = plt.scatter(np.arange(len(CBS_comp)), CBS_comp, marker = 'o', color = newscolors['cbs'] , label = 'CBS', alpha = .75)
cnn_scatter = plt.scatter(np.arange(len(CNN_comp)), CNN_comp, marker = 'o', color = newscolors['cnn'] , label = 'CNN', alpha = .75)
fx_scatter = plt.scatter(np.arange(len(FX_comp)), FX_comp, marker = 'o', color = newscolors['fox'] , label = 'Fox', alpha = .75)
nyt_scatter = plt.scatter(np.arange(len(NYT_comp)), NYT_comp, marker = 'o', color = newscolors['nytimes'] , label = 'New York Times', alpha = .75)

#create grid background
plt.grid(True, color = '#694670')

#legend and titles
plt.legend(handles=[bbc_scatter, cbs_scatter, cnn_scatter, fx_scatter, nyt_scatter], loc=(1.04,.5), title = 'Media Sources')
plt.suptitle('Sentiment Analysis of Media Tweets 3/30/2018')
plt.xlabel('Tweets Ago')
plt.ylabel('Tweet Polarity')

#plot all compunds
plt.show()

# %%
#get average of each media compound
bbc_total_comp = BBC_comp.mean()
cbs_total_comp = CBS_comp.mean()
cnn_total_comp = CNN_comp.mean()
fx_total_comp = FX_comp.mean()
nyt_total_comp = NYT_comp.mean()

#x-axis and media values
overal_media = [bbc_total_comp, cbs_total_comp, cnn_total_comp, fx_total_comp, nyt_total_comp]
x_axis = np.arange(len(overal_media))

#media colors
hexcodes = ['#8EE5EE', '#3D9140', '#DC143C', '#3D59AB', '#FFD700']

#change the values to media handles
tick_loactions = [value for value in x_axis]
plt.xticks(tick_loactions, ['BBC', 'CBS', 'CNN', 'Fox', 'NYT'])

#create bar chart
plt.bar(x_axis, overal_media, color = hexcodes)

#title and y axis label
plt.suptitle('Overall Media Sentiment based on Twitter 3/30/2018')
plt.ylabel('Tweet Polarity')

#plot bar chart
plt.show()
